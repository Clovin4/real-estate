# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
# read in data
df = pd.read_csv('/Users/christianl/Desktop/weekly_housing_market_data_most_recent.tsv000', sep='\t')

# %%
# drop rows with duration of '4 weeks' and '12 weeks'
df = df[df['duration'] != '4 weeks']
df = df[df['duration'] != '12 weeks']
df.head()
# Out:
#     region_id  region_type_id          region_name region_type period_begin  \
# 2        2266               5     Creek County, OK      county   2017-05-29
# 5        2380               5  Crawford County, PA      county   2017-05-29
# 8        2715               5    Fisher County, TX      county   2017-05-29
# 11       2766               5     Jones County, TX      county   2017-05-29
# 14       3037               5       Chesapeake, VA      county   2017-05-29
#
#     period_end duration  total_homes_sold  total_homes_sold_yoy  \
# 2   2017-06-04  1 weeks              17.0             -0.150000
# 5   2017-06-04  1 weeks               4.0             -0.200000
# 8   2017-06-04  1 weeks               1.0                   NaN
# 11  2017-06-04  1 weeks               3.0              2.000000
# 14  2017-06-04  1 weeks             125.0              0.302083
#
#     average_homes_sold  ...  average_adjustment_average_homes_sold  \
# 2                 17.0  ...                                    NaN
# 5                  4.0  ...                                    NaN
# 8                  1.0  ...                                    NaN
# 11                 3.0  ...                                    NaN
# 14               125.0  ...                                    NaN
#
#     adjusted_average_homes_sold  average_adjustment_average_new_listings  \
# 2                          17.0                                      NaN
# 5                           4.0                                      NaN
# 8                           1.0                                      NaN
# 11                          3.0                                      NaN
# 14                        125.0                                      NaN
#
#     adjusted_average_new_listings  average_adjustment_pending_sales  \
# 2                            17.0                               NaN
# 5                             6.0                               NaN
# 8                             NaN                               NaN
# 11                            2.0                               NaN
# 14                          113.0                               NaN
#
#     adjusted_pending_sales  adjusted_average_homes_delisted_yoy  \
# 2                      7.0                                 -0.5
# 5                      2.0                                  NaN
# 8                      NaN                                  NaN
# 11                     NaN                                  NaN
# 14                    82.0                                  0.0
#
#     adjusted_average_homes_sold_yoy  adjusted_average_new_listings_yoy  \
# 2                         -0.150000                          -0.150000
# 5                         -0.200000                          -0.142857
# 8                               NaN                                NaN
# 11                         2.000000                          -0.714286
# 14                         0.302083                          -0.017391
#
#     adjusted_pending_sales_yoy
# 2                    -0.125000
# 5                     1.000000
# 8                          NaN
# 11                         NaN
# 14                    0.782609
#
# [5 rows x 102 columns]

# %%
len(df.region_name.unique())
# Out:
# 3859

# %%
# find the top 10 regions with the most data
df['region_name'].value_counts().head(10)
# Out:
# Creek County, OK            328
# El Dorado County, CA        328
# Calhoun County, AL          328
# Surry County, VA            328
# Petersburg, VA              328
# Columbia County, WI         328
# Bemidji, MN metro area      328
# Athens, OH metro area       328
# Corsicana, TX metro area    328
# Kerrville, TX metro area    328
# Name: region_name, dtype: int64

# %%
# find the top 10 regions with the least data
df['region_name'].value_counts().tail(10)
# Out:
# Dundy County, NE        20
# Cheyenne County, NE     20
# Jackson County, SD      16
# Thomas County, NE       12
# Wichita County, KS      12
# Dawes County, NE        11
# Deuel County, NE        10
# McPherson County, NE    10
# Kenedy County, TX        8
# Sheridan County, NE      2
# Name: region_name, dtype: int64

# %%
# find data where region_name contains 'Nashville'
df_nash = df[df['region_name'].str.contains('Nashville')]

# %%
df_nash.head()
# Out:
#        region_id  region_type_id               region_name region_type  \
# 18068      34980              -2  Nashville, TN metro area       metro
# 26364      34980              -2  Nashville, TN metro area       metro
# 49919      34980              -2  Nashville, TN metro area       metro
# 59555      34980              -2  Nashville, TN metro area       metro
# 71393      34980              -2  Nashville, TN metro area       metro
#
#       period_begin  period_end duration  total_homes_sold  \
# 18068   2017-01-02  2017-01-08  1 weeks             425.0
# 26364   2017-02-13  2017-02-19  1 weeks             541.0
# 49919   2017-01-09  2017-01-15  1 weeks             499.0
# 59555   2017-04-10  2017-04-16  1 weeks             617.0
# 71393   2017-04-17  2017-04-23  1 weeks             775.0
#
#        total_homes_sold_yoy  average_homes_sold  ...  \
# 18068             -0.057650               425.0  ...
# 26364              0.113169               541.0  ...
# 49919             -0.005976               499.0  ...
# 59555             -0.146611               617.0  ...
# 71393              0.108727               775.0  ...
#
#        average_adjustment_average_homes_sold  adjusted_average_homes_sold  \
# 18068                                    NaN                        425.0
# 26364                                    NaN                        541.0
# 49919                                    NaN                        499.0
# 59555                                    NaN                        617.0
# 71393                                    NaN                        775.0
#
#        average_adjustment_average_new_listings  adjusted_average_new_listings  \
# 18068                                      NaN                          694.0
# 26364                                      NaN                          770.0
# 49919                                      NaN                          726.0
# 59555                                      NaN                          836.0
# 71393                                      NaN                          950.0
#
#        average_adjustment_pending_sales  adjusted_pending_sales  \
# 18068                               NaN                   335.0
# 26364                               NaN                   392.0
# 49919                               NaN                   395.0
# 59555                               NaN                   543.0
# 71393                               NaN                   596.0
#
#        adjusted_average_homes_delisted_yoy  adjusted_average_homes_sold_yoy  \
# 18068                            -0.182540                        -0.057650
# 26364                            -0.213592                         0.113169
# 49919                            -0.071429                        -0.005976
# 59555                            -0.210000                        -0.146611
# 71393                            -0.022727                         0.108727
#
#        adjusted_average_new_listings_yoy  adjusted_pending_sales_yoy
# 18068                          -0.023910                    0.024465
# 26364                          -0.027778                    0.088889
# 49919                          -0.017591                    0.109551
# 59555                          -0.212064                   -0.109836
# 71393                          -0.102079                   -0.088685
#
# [5 rows x 102 columns]

# %%
# find beginning and end dates of data
print(df_nash['period_begin'].min())
print(df_nash['period_end'].max())
# Out:
# 2017-01-02
# 2023-04-16

# %%
# find all counties in the state of Tennessee
df_tn = df[df['region_name'].str.contains('TN')]

# %%
df_tn.region_name.unique()
# Out:
# array(['Martin, TN metro area', 'Lincoln County, TN',
#        'Sullivan County, TN', 'Cookeville, TN metro area',
#        'Henderson County, TN', 'Lawrence County, TN', 'Tipton County, TN',
#        'Greeneville, TN metro area', 'Cheatham County, TN',
#        'Pickett County, TN', 'Union County, TN', 'Newport, TN metro area',
#        'Washington County, TN', 'Dyer County, TN', 'Grainger County, TN',
#        'Johnson City, TN metro area', 'Morgan County, TN',
#        'Hardin County, TN', 'Giles County, TN', 'Moore County, TN',
#        'Meigs County, TN', 'Blount County, TN', 'Wilson County, TN',
#        'Kingsport, TN metro area', 'Bradley County, TN',
#        'Carter County, TN', 'Cumberland County, TN',
#        'Paris, TN metro area', 'Madison County, TN',
#        'Williamson County, TN', 'Rhea County, TN',
#        'Dyersburg, TN metro area', 'Marion County, TN',
#        'McMinnville, TN metro area', 'Clay County, TN',
#        'White County, TN', 'Gibson County, TN', 'Montgomery County, TN',
#        'Sevierville, TN metro area', 'McNairy County, TN',
#        'Macon County, TN', 'Scott County, TN', 'Carroll County, TN',
#        'Cleveland, TN metro area', 'Shelbyville, TN metro area',
#        'Putnam County, TN', 'Benton County, TN', 'Stewart County, TN',
#        'Lewis County, TN', 'Hamilton County, TN', 'Lake County, TN',
#        'Davidson County, TN', 'Nashville, TN metro area',
#        'Knox County, TN', 'Sevier County, TN', 'Unicoi County, TN',
#        'Polk County, TN', 'Warren County, TN', 'Wayne County, TN',
#        'Franklin County, TN', 'Greene County, TN', 'DeKalb County, TN',
#        'Cannon County, TN', 'Dickson County, TN', 'Houston County, TN',
#        'Memphis, TN metro area', 'Fentress County, TN',
#        'Maury County, TN', 'Dayton, TN metro area', 'Hancock County, TN',
#        'Jefferson County, TN', 'Bedford County, TN',
#        'Morristown, TN metro area', 'Humphreys County, TN',
#        'Weakley County, TN', 'Hamblen County, TN', 'Hardeman County, TN',
#        'Henry County, TN', 'Smith County, TN', 'Grundy County, TN',
#        'Robertson County, TN', 'Hawkins County, TN',
#        'Sequatchie County, TN', 'Marshall County, TN',
#        'Lawrenceburg, TN metro area', 'Coffee County, TN',
#        'Athens, TN metro area', 'Hickman County, TN', 'Cocke County, TN',
#        'Tullahoma, TN metro area', 'Bledsoe County, TN',
#        'Sumner County, TN', 'Lewisburg, TN metro area',
#        'Rutherford County, TN', 'Anderson County, TN',
#        'Campbell County, TN', 'Jackson, TN metro area',
#        'Chester County, TN', 'Trousdale County, TN', 'Fayette County, TN',
#        'Crossville, TN metro area', 'Claiborne County, TN',
#        'Overton County, TN', 'Knoxville, TN metro area',
#        'Decatur County, TN', 'Monroe County, TN', 'Jackson County, TN',
#        'Shelby County, TN', 'Brownsville, TN metro area',
#        'Perry County, TN', 'Clarksville, TN metro area',
#        'Johnson County, TN', 'Obion County, TN', 'Lauderdale County, TN',
#        'Loudon County, TN', 'Haywood County, TN',
#        'Union City, TN metro area', 'Crockett County, TN',
#        'McMinn County, TN', 'Roane County, TN', 'Van Buren County, TN'],
#       dtype=object)

# %%
# find county data whith region name containing the following: 'Cheatham County, Davidson County, Dickson County, Maury County, Montgomery County, Robertson County, Rutherford County, Sumner County'
df_tn = df_tn[df_tn['region_name'].str.contains('Cheatham County|Davidson County|Dickson County|Maury County|Montgomery County|Robertson County|Rutherford County|Sumner County')]

# %%
df_tn.region_name.unique()
# Out:
# array(['Cheatham County, TN', 'Montgomery County, TN',
#        'Davidson County, TN', 'Dickson County, TN', 'Maury County, TN',
#        'Robertson County, TN', 'Sumner County, TN',
#        'Rutherford County, TN'], dtype=object)

# %%
#
